# %% [markdown]
# # Web Scraping In Python to get Information about Courses on Udacity
# I wanted to see which courses on Udacity formed part of the different Nanodegrees.
# I first got a list of all the courses (accessible on https://www.udacity.com/courses/all) and then visited the URL for each course to extract info about the Nanodegree it belonged to.
#
# Dataquest has an awesome tutorial on how to do web scraping, which I recommend you go through if you are new to it. https://www.dataquest.io/blog/web-scraping-beautifulsoup/
#
# This makes use of BeautifulSoup to easily extract HTML elements from the content in a response of getting a web page.

# %%
from bs4 import BeautifulSoup
import requests

response = requests.get("https://www.udacity.com/courses/all")
html_soup = BeautifulSoup(response.content, 'html.parser')

#find all the URLs (items in the html where href exists)
url = html_soup.find_all(href=True)

#Iterate through the urls, and only return the ones that contain course and --
links = []
for u in url:
    if (u['href'].find('course') != -1):
        if (u['href'].find('--') != -1):
            if (u['href'].find('nanodegree') == -1):
                links.append(u['href'])
            
#remove duplicates by converting the list of links to a set, then back to a list
links = list(set(links)) 
links
# Out:
# ['/course/artificial-intelligence-for-robotics--cs373',
#  '/course/engagement-monetization-mobile-games--ud407',
#  '/course/object-oriented-javascript--ud015',
#  '/course/how-to-make-an-ios-app--ud607',
#  '/course/model-building-and-validation--ud919',
#  '/course/learn-unreal-vr-foundations--nd117',
#  '/course/strengthen-your-linkedin-network-and-brand--ud242',
#  '/course/data-analysis-with-r--ud651',
#  '/course/high-performance-computing--ud281',
#  '/course/data-structures-and-algorithms-in-swift--ud1011',
#  '/course/javascript-design-patterns--ud989',
#  '/course/differential-equations-in-action--cs222',
#  '/course/embedded-systems--ud169',
#  '/course/swift-for-beginners--ud1022',
#  '/course/android-basics-data-storage--ud845',
#  '/course/design-of-computer-programs--cs212',
#  '/course/big-data-analytics-in-healthcare--ud758',
#  '/course/robotics-software-engineer--nd209',
#  '/course/android-auto-development--ud875C',
#  '/course/android-performance--ud825',
#  '/course/browser-rendering-optimization--ud860',
#  '/course/http-web-servers--ud303',
#  '/course/intro-to-inferential-statistics--ud201',
#  '/course/responsive-web-design-fundamentals--ud893',
#  '/course/educational-technology--ud915',
#  '/course/segmentation-and-clustering--ud981',
#  '/course/software-analysis-testing--ud333',
#  '/course/javascript-promises--ud898',
#  '/course/how-to-build-a-startup--ep245',
#  '/course/product-design--ud509',
#  '/course/applied-cryptography--cs387',
#  '/course/intro-to-progressive-web-apps--ud811',
#  '/course/passwordless-login-solutions-for-android--ud357',
#  '/course/introduction-to-virtual-reality--ud1012',
#  '/course/object-oriented-javascript--ud711',
#  '/course/localization-essentials--ud610',
#  '/course/intro-to-relational-databases--ud197',
#  '/course/data-analysis-and-visualization--ud404',
#  '/course/app-monetization--ud518',
#  '/course/intro-to-data-analysis--ud170',
#  '/course/intro-to-jquery--ud245',
#  '/course/offline-web-applications--ud899',
#  '/course/version-control-with-git--ud123',
#  '/course/design-sprint-foundations--nd201',
#  '/course/writing-readmes--ud777',
#  '/course/asynchronous-javascript-requests--ud109',
#  '/course/html5-canvas--ud292',
#  '/course/kotlin-for-android-developers--ud888',
#  '/course/android-interview-prep--ud241',
#  '/course/data-visualization-in-tableau--ud1006',
#  '/course/refresh-your-resume--ud243',
#  '/course/intro-to-hadoop-and-mapreduce--ud617',
#  '/course/interactive-3d-graphics--cs291',
#  '/course/intro-to-devops--ud611',
#  '/course/intro-to-machine-learning--ud120',
#  '/course/software-architecture-design--ud821',
#  '/course/compilers-theory-and-practice--ud168',
#  '/course/data-science-interview-prep--ud944',
#  '/course/intro-to-self-driving-cars--nd113',
#  '/course/new-android-fundamentals--ud851',
#  '/course/craft-your-cover-letter--ud244',
#  '/course/designing-restful-apis--ud388',
#  '/course/passwordless-login-solutions-for-ios--ud1028',
#  '/course/firebase-analytics-android--ud354',
#  '/course/intro-to-javascript--ud803',
#  '/course/what-is-programming--ud994',
#  '/course/2d-game-development-with-libgdx--ud405',
#  '/course/intro-to-theoretical-computer-science--cs313',
#  '/course/advanced-android-app-development--ud855',
#  '/course/client-server-communication--ud897',
#  '/course/javascript-testing--ud549',
#  '/course/firebase-in-a-weekend-by-google-android--ud0352',
#  '/course/intro-to-backend--ud171',
#  '/course/ios-networking-with-swift--ud421',
#  '/course/software-debugging--cs259',
#  '/course/creating-an-analytical-dataset--ud977',
#  '/course/health-informatics-in-the-cloud--ud809',
#  '/course/vr-software-development--ud1014',
#  '/course/learn-arkit-using-swift--ud116',
#  '/course/grand-central-dispatch-gcd--ud576',
#  '/course/web-tooling-automation--ud892',
#  '/course/android-basics-networking--ud843',
#  '/course/intro-to-physics--ph100',
#  '/course/ios-persistence-and-core-data--ud325',
#  '/course/responsive-images--ud882',
#  '/course/intro-to-the-design-of-everyday-things--design101',
#  '/course/intro-to-programming--ud000',
#  '/course/configuring-linux-web-servers--ud299',
#  '/course/building-high-conversion-web-forms--ud890',
#  '/course/eigenvectors-and-eigenvalues--ud104',
#  '/course/front-end-frameworks--ud894',
#  '/course/data-structures-and-algorithms-in-python--ud513',
#  '/course/optimize-your-github--ud247',
#  '/course/core-ml--ud1038',
#  '/course/developing-android-apps-with-kotlin--ud9012',
#  '/course/how-to-make-a-platformer-using-libgdx--ud406',
#  '/course/machine-learning-unsupervised-learning--ud741',
#  '/course/c-for-programmers--ud210',
#  '/course/deep-learning--ud730',
#  '/course/cyber-physical-systems-security--ud279',
#  '/course/firebase-in-a-weekend-by-google-ios--ud0351',
#  '/course/android-basics-user-interface--ud834',
#  '/course/linear-algebra-refresher-course--ud953',
#  '/course/deep-learning-pytorch--ud188',
#  '/course/the-mvc-pattern-in-ruby--ud270',
#  '/course/intro-to-ajax--ud110',
#  '/course/full-stack-interview-prep--ud252',
#  '/course/shell-workshop--ud206',
#  '/course/introduction-to-computer-vision--ud810',
#  '/course/kotlin-bootcamp-for-programmers--ud9011',
#  '/course/time-series-forecasting--ud980',
#  '/course/how-to-use-git-and-github--ud775',
#  '/course/tales-from-the-genome--bio110',
#  '/course/intro-to-ios-app-development-with-swift--ud585',
#  '/course/high-performance-computer-architecture--ud007',
#  '/course/ab-testing--ud257',
#  '/course/build-native-mobile-apps-with-flutter--ud905',
#  '/course/intro-to-html-and-css--ud001',
#  '/course/gt-refresher-advanced-os--ud098',
#  '/course/statistics--st095',
#  '/course/auto-layout--ud1026',
#  '/course/programming-languages--cs262',
#  '/course/intro-to-point-click-app-development--ud162',
#  '/course/sql-for-data-analysis--ud198',
#  '/course/material-design-for-android-developers--ud862',
#  '/course/get-your-startup-started--ud806',
#  '/course/knowledge-based-ai-cognitive-systems--ud409',
#  '/course/mobile-design-and-usability-for-android--ud358',
#  '/course/google-maps-apis--ud864',
#  '/course/gradle-for-android-and-java--ud867',
#  '/course/server-side-swift--ud1031',
#  '/course/front-end-interview-prep--ud250',
#  '/course/real-time-analytics-with-apache-storm--ud381',
#  '/course/intro-to-descriptive-statistics--ud827',
#  '/course/java-programming-basics--ud282',
#  '/course/github-collaboration--ud456',
#  '/course/introduction-to-python--ud1110',
#  '/course/problem-solving-with-advanced-analytics--ud976',
#  '/course/es6-javascript-improved--ud356',
#  '/course/networking-for-web-developers--ud256',
#  '/course/self-driving-car-fundamentals-featuring-apollo--ud0419',
#  '/course/intro-to-computer-science--cs101',
#  '/course/advanced-operating-systems--ud189',
#  '/course/intro-to-data-science--ud359',
#  '/course/intro-to-information-security--ud459',
#  '/course/swift-for-developers--ud1025',
#  '/course/human-computer-interaction--ud400',
#  '/course/intro-to-artificial-intelligence--cs271',
#  '/course/software-development-process--ud805',
#  '/course/deploying-applications-with-heroku--ud272',
#  '/course/reinforcement-learning--ud600',
#  '/course/learn-arkit-using-unity--ud114',
#  '/course/computational-photography--ud955',
#  '/course/website-performance-optimization--ud884',
#  '/course/software-testing--cs258',
#  '/course/artificial-intelligence--ud954',
#  '/course/mobile-design-and-usability-for-ios--ud1034',
#  '/course/xcode-debugging--ud774',
#  '/course/intro-to-algorithms--cs215',
#  '/course/machine-learning--ud262',
#  '/course/omscs-student-orientation--gt101',
#  '/course/android-basics-multiscreen-apps--ud839',
#  '/course/how-to-install-android-studio--ud808',
#  '/course/vr-interview-prep--ud251',
#  '/course/data-wrangling-with-mongodb--ud032',
#  '/course/object-oriented-programming-in-java--ud283',
#  '/course/cyber-physical-systems-design-analysis--ud9876',
#  '/course/objective-c-for-swift-developers--ud1009',
#  '/course/firebase-analytics-ios--ud353',
#  '/course/ab-testing--ud979',
#  '/course/google-adwords--nd124',
#  '/course/programming-foundations-with-python--ud036',
#  '/course/introduction-to-graduate-algorithms--ud401',
#  '/course/app-marketing--ud719',
#  '/course/introduction-to-operating-systems--ud923',
#  '/course/android-basics-user-input--ud836',
#  '/course/intro-to-psychology--ps001',
#  '/course/learn-swift-programming-syntax--ud902',
#  '/course/full-stack-foundations--ud088',
#  '/course/computer-networking--ud436',
#  '/course/network-security--ud199',
#  '/course/computability-complexity-algorithms--ud061',
#  '/course/deploying-a-hadoop-cluster--ud1000',
#  '/course/uikit-fundamentals--ud788',
#  '/course/machine-learning-for-trading--ud501',
#  '/course/web-accessibility--ud891',
#  '/course/classification-models--ud978',
#  '/course/data-visualization-and-d3js--ud507',
#  '/course/ux-design-for-mobile-developers--ud849',
#  '/course/scalable-microservices-with-kubernetes--ud615',
#  '/course/ios-interview-prep--ud240',
#  '/course/javascript-and-the-dom--ud117',
#  '/course/rapid-prototyping--ud723',
#  '/course/ai-for-trading--nd880',
#  '/course/database-systems-concepts-design--ud150',
#  '/course/intro-to-statistics--st101',
#  '/course/authentication-authorization-oauth--ud330',
#  '/course/vr-scenes-and-objects--ud1013',
#  '/course/linux-command-line-basics--ud595',
#  '/course/dynamic-web-applications-with-sinatra--ud268']

# %%
len(links)
# Out:
# 200

# %% [markdown]
# There are 200 unique links that belong to the different courses on Udacity. These are the courses that can be done without enrolling in a nanodegree.
#
# Each course URL will be visited in the following code to extract the information needed. The relevent HTML tags and class names were extracted by visiting the URL, right clicking on the element of interest and selecting Inspect to view the related HTML. This could then be used with the BeautifulSoup find and find_all functions to get the information.

# %%
import time
from random import randint

#initilise the lists to store the extracted info
course_names = []
course_urls = []
course_nanodegrees = []
course_costs = []

# Preparing the monitoring of the loop
start_time = time.time()
requests_count = 0

#iterate through each link to extract info about the nano degree it belongs to and the cost
for i in range(len(links)):
    #need to make requests at random times in order to not be blocked by website
    time.sleep(randint(2,6)) 
    url = "https://www.udacity.com" + links[i]
    response = requests.get(url)
    content = response.content
    html_soup = BeautifulSoup(content, 'html.parser')
    
    # Monitor the requests
    requests_count += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests_count, requests_count/elapsed_time))
    #clear_output(wait = True)
    
    # Break the loop if the number of requests is greater than expected
    if requests_count > 250:
        warn('Number of requests was greater than expected.')  
        break 
    
    try:
        nanodegree = html_soup.find('h3',class_="h1 hero__nanodegree--title").text
    except:
        nanodegree = 'None'
    try:
        course_name = html_soup.find('h1',class_='hero__course--title').text
    except:
        course_name = 'None'
    try:
        cost = html_soup.find('h6',class_='hero__course--type').text
    except:
        cost = 'None'
    course_names.append(course_name)
    course_urls.append(url)
    course_nanodegrees.append(nanodegree)
    course_costs.append(cost)
# Out:
# Request:1; Frequency: 0.17667353821036022 requests/s
# Request:2; Frequency: 0.21928629575410366 requests/s
# Request:3; Frequency: 0.2584761215221361 requests/s
# Request:4; Frequency: 0.22902981383188756 requests/s
# Request:5; Frequency: 0.2365505733454123 requests/s
# Request:6; Frequency: 0.2304757296488512 requests/s
# Request:7; Frequency: 0.20998458772770595 requests/s
# Request:8; Frequency: 0.216026468638043 requests/s
# Request:9; Frequency: 0.22592739192625771 requests/s
# Request:10; Frequency: 0.2294515947997564 requests/s
# Request:11; Frequency: 0.21815650310835355 requests/s
# Request:12; Frequency: 0.21035776320594227 requests/s
# Request:13; Frequency: 0.2179981739328464 requests/s
# Request:14; Frequency: 0.2245864723987871 requests/s
# Request:15; Frequency: 0.21756654644337867 requests/s
# Request:16; Frequency: 0.2154386827341679 requests/s
# Request:17; Frequency: 0.21864592059903892 requests/s
# Request:18; Frequency: 0.2127145987440594 requests/s
# Request:19; Frequency: 0.20985016844926185 requests/s
# Request:20; Frequency: 0.20794339181723875 requests/s
# Request:21; Frequency: 0.20811808349306213 requests/s
# Request:197; Frequency: 0.20877844318405198 requests/s
# Request:198; Frequency: 0.20830010393354403 requests/s
# Request:199; Frequency: 0.2085444114484643 requests/s
# Request:200; Frequency: 0.20860881934519734 requests/s

# %%
#Convert the lists to a dataframe
import pandas as pd
courses_df = pd.DataFrame({'Name': course_names,
                          'URL': course_urls,
                          'Nanodegree': course_nanodegrees,
                          'Cost':course_costs})
courses_df = courses_df.sort_values('Nanodegree')
print(courses_df.info())
courses_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 176 to 145
# Data columns (total 4 columns):
# Name          200 non-null object
# URL           200 non-null object
# Nanodegree    200 non-null object
# Cost          200 non-null object
# dtypes: object(4)
# memory usage: 7.8+ KB
# None
#                                          Name  \
# 176                       Intro to Psychology
# 14               Android Basics: Data Storage
# 175                Android Basics: User Input
# 161          Android Basics: Multiscreen Apps
# 134                   Java Programming Basics
# 81                 Android Basics: Networking
# 127   Mobile Design and Usability for Android
# 32   Passwordless Login Solutions for Android
# 35                    Localization Essentials
# 129               Gradle for Android and Java
# 162             How to Install Android Studio
# 30                       Applied Cryptography
# 55             Software Architecture & Design
# 142                Advanced Operating Systems
# 63                Firebase Analytics: Android
# 71             Firebase in a Weekend: Android
# 66            2D Game Development with libGDX
# 165       Object Oriented Programming in Java
# 124    Material Design for Android Developers
# 68           Advanced Android App Development
# 109           Kotlin Bootcamp for Programmers
# 18                   Android Auto Development
# 19                        Android Performance
# 94        Developing Android Apps with Kotlin
# 188           UX Design for Mobile Developers
# 95      How to Make a Platformer Using libGDX
# 144             Intro to Information Security
# 24                     Educational Technology
# 152                 Computational Photography
# 76            Health Informatics in the Cloud
# ..                                        ...
# 85     Intro to the Design of Everyday Things
# 197                     VR Scenes and Objects
# 1    Engagement & Monetization | Mobile Games
# 151                   Learn ARKit using Unity
# 33            Introduction to Virtual Reality
# 77                    VR Software Development
# 118              GT - Refresher - Advanced OS
# 114    High Performance Computer Architecture
# 52                    Interactive 3D Graphics
# 130                         Server-Side Swift
# 3                      How to Make an iOS App
# 100                Firebase in a Weekend: iOS
# 192                         Rapid Prototyping
# 73                  iOS Networking with Swift
# 113   Intro to iOS App Development with Swift
# 156       Mobile Design and Usability for iOS
# 78                    Learn ARKit using Swift
# 168                   Firebase Analytics: iOS
# 183                        UIKit Fundamentals
# 79               Grand Central Dispatch (GCD)
# 120                                AutoLayout
# 83              iOS Persistence and Core Data
# 166  Cyber-Physical Systems Design & Analysis
# 177            Learn Swift Programming Syntax
# 167          Objective-C for Swift Developers
# 62       Passwordless Login Solutions for iOS
# 38                           App Monetization
# 172       Introduction to Graduate Algorithms
# 157                           Xcode Debugging
# 145                      Swift for Developers
#
#                                                    URL  \
# 176  https://www.udacity.com/course/intro-to-psycho...
# 14   https://www.udacity.com/course/android-basics-...
# 175  https://www.udacity.com/course/android-basics-...
# 161  https://www.udacity.com/course/android-basics-...
# 134  https://www.udacity.com/course/java-programmin...
# 81   https://www.udacity.com/course/android-basics-...
# 127  https://www.udacity.com/course/mobile-design-a...
# 32   https://www.udacity.com/course/passwordless-lo...
# 63         Android Developer  Free Course
# 71         Android Developer  Free Course
# 66         Android Developer  Free Course
# 165        Android Developer  Free Course
# 124        Android Developer  Free Course
# 68         Android Developer  Free Course
# 109        Android Developer  Free Course
# 18         Android Developer  Free Course
# 19         Android Developer  Free Course
# 94         Android Developer  Free Course
# 188        Android Developer  Free Course
# 95         Android Developer  Free Course
# 144  Artificial Intelligence  Free Course
# 24   Artificial Intelligence  Free Course
# 152  Artificial Intelligence  Free Course
# 76   Artificial Intelligence  Free Course
# ..                       ...          ...
# 85              VR Developer  Free Course
# 197             VR Developer  Free Course
# 1               VR Developer  Free Course
# 151             VR Developer  Free Course
# 33              VR Developer  Free Course
# 77              VR Developer  Free Course
# 118             VR Developer  Free Course
# 114             VR Developer  Free Course
# 52              VR Developer  Free Course
# 130            iOS Developer  Free Course
# 3              iOS Developer  Free Course
# 100            iOS Developer  Free Course
# 192            iOS Developer  Free Course
# 73             iOS Developer  Free Course
# 113            iOS Developer  Free Course
# 156            iOS Developer  Free Course
# 78             iOS Developer  Free Course
# 168            iOS Developer  Free Course
# 183            iOS Developer  Free Course
# 79             iOS Developer  Free Course
# 120            iOS Developer  Free Course
# 83             iOS Developer  Free Course
# 166            iOS Developer  Free Course
# 177            iOS Developer  Free Course
# 167            iOS Developer  Free Course
# 62             iOS Developer  Free Course
# 38             iOS Developer  Free Course
# 172            iOS Developer  Free Course
# 157            iOS Developer  Free Course
# 145            iOS Developer  Free Course
#
# [200 rows x 4 columns]

# %%
#Save to csv file
courses_df.to_csv('Udacity_Courses.csv')

# %% [markdown]
# To see which courses belonged to the Data Analyst degree, the courses data frame was filtered and a new data frame was created

# %%
data_analyst = courses_df[courses_df['Nanodegree'] == 'Data Analyst']
data_analyst
# Out:
#                                 Name  \
# 26       Software Analysis & Testing
# 115                      A/B Testing
# 146       Human-Computer Interaction
# 187     Data Visualization and D3.js
# 7               Data Analysis with R
# 37   Data Analysis and Visualization
# 173                    App Marketing
# 49     Data Visualization in Tableau
# 121            Programming Languages
# 164      Data Wrangling with MongoDB
# 133  Intro to Descriptive Statistics
#
#                                                    URL    Nanodegree  \
# 26   https://www.udacity.com/course/software-analys...  Data Analyst
# 115   https://www.udacity.com/course/ab-testing--ud257  Data Analyst
# 146  https://www.udacity.com/course/human-computer-...  Data Analyst
# 187  https://www.udacity.com/course/data-visualizat...  Data Analyst
# 7    https://www.udacity.com/course/data-analysis-w...  Data Analyst
# 37   https://www.udacity.com/course/data-analysis-a...  Data Analyst
# 173  https://www.udacity.com/course/app-marketing--...  Data Analyst
# 49   https://www.udacity.com/course/data-visualizat...  Data Analyst
# 121  https://www.udacity.com/course/programming-lan...  Data Analyst
# 164  https://www.udacity.com/course/data-wrangling-...  Data Analyst
# 133  https://www.udacity.com/course/intro-to-descri...  Data Analyst
#
#             Cost
# 26   Free Course
# 115  Free Course
# 146  Free Course
# 187  Free Course
# 7    Free Course
# 37   Free Course
# 173  Free Course
# 49   Free Course
# 121  Free Course
# 164  Free Course
# 133  Free Course
